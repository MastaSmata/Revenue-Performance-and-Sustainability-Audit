# %%
import sys

print(sys.executable)
# Out:
# C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost", user="root", password="mastasmata1234", database="revenue_analysis"
)
cursor = conn.cursor()

# %%
total_revenue = pd.read_sql("SELECT * FROM vw_total_revenue", conn)
total_revenue
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\173391977.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   total_revenue = pd.read_sql("SELECT * FROM vw_total_revenue", conn)
#    total_revenue_sum
# 0        10428952.48

# %%
aov = pd.read_sql("SELECT * FROM vw_aov_per_customer", conn)
aov.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\3135476444.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aov = pd.read_sql("SELECT * FROM vw_aov_per_customer", conn)
#    customer_id  total_revenue  total_orders          aov
# 0         1001       19561.51            16  1222.594375
# 1         1011        2734.59             1  2734.590000
# 2         1021       16762.71             6  2793.785000
# 3         1031        7474.32             1  7474.320000
# 4         1041        5162.34             3  1720.780000

# %%
customer_growth = pd.read_sql("SELECT * FROM vw_customer_growth_yoy", conn)

customer_growth
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\3838618199.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customer_growth = pd.read_sql("SELECT * FROM vw_customer_growth_yoy", conn)
#    year  total_customers
# 0  2013               56
# 1  2014               74
# 2  2015              124
# 3  2016              300
# 4  2017               13

# %%
trend = pd.read_sql("SELECT * FROM vw_revenue_trend", conn)
trend.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\1181986341.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   trend = pd.read_sql("SELECT * FROM vw_revenue_trend", conn)
#      month    revenue
# 0  2015-10  245570.10
# 1  2015-11  242340.37
# 2  2015-12  267005.62
# 3  2016-01  269629.45
# 4  2016-02  272858.32

# %%
order_frequency = pd.read_sql("SELECT * FROM vw_order_frequency_yoy", conn)

order_frequency
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\671312966.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_frequency = pd.read_sql("SELECT * FROM vw_order_frequency_yoy", conn)
#    year  total_orders  total_customers  avg_order_frequency
# 0  2013            56               56               1.0000
# 1  2014           739               74               9.9865
# 2  2015          1023              124               8.2500
# 3  2016          2219              300               7.3967
# 4  2017            13               13               1.0000

# %%
customer_status = pd.read_sql("SELECT * FROM vw_customer_growth_status", conn)

customer_status.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\2129075134.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customer_status = pd.read_sql("SELECT * FROM vw_customer_growth_status", conn)
#    customer_id  year   revenue  prev_revenue growth_status
# 0         1001  2015   3467.64           NaN           New
# 1         1001  2016  16093.87       3467.64       Growing
# 2         1011  2016   2734.59           NaN           New
# 3         1021  2015   8264.72           NaN           New
# 4         1021  2016   8497.99       8264.72       Growing

# %%
top_tier = pd.read_sql("SELECT * FROM vw_top_tier_revenue", conn)

top_tier.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\3690533732.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   top_tier = pd.read_sql("SELECT * FROM vw_top_tier_revenue", conn)
# Empty DataFrame
# Columns: [year, customer_id, total_revenue]
# Index: []

# %%
revenue_loss = pd.read_sql("SELECT * FROM vw_top_tier_revenue_loss", conn)

revenue_loss.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\3487222155.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   revenue_loss = pd.read_sql("SELECT * FROM vw_top_tier_revenue_loss", conn)
# Empty DataFrame
# Columns: [customer_id, rev_2024, rev_2025, revenue_change, pct_change]
# Index: []

# %%
revenue_trend = pd.read_sql("SELECT * FROM vw_revenue_trend", conn)

revenue_trend.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\2485888704.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   revenue_trend = pd.read_sql("SELECT * FROM vw_revenue_trend", conn)
#      month    revenue
# 0  2015-10  245570.10
# 1  2015-11  242340.37
# 2  2015-12  267005.62
# 3  2016-01  269629.45
# 4  2016-02  272858.32

# %%
plt.figure(figsize=(12, 6))

plt.plot(revenue_trend["month"], revenue_trend["revenue"])

plt.title("Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")

plt.xticks(rotation=45)

plt.show()

# %%
status_counts = customer_status["growth_status"].value_counts(normalize=True) * 100

plt.figure(figsize=(8, 6))

status_counts.plot(kind="bar", stacked=True)

plt.title("Customer Growth Status")
plt.ylabel("Percentage")

plt.show()

# %%
waterfall = pd.read_sql("SELECT * FROM vw_revenue_by_region", conn)

plt.figure(figsize=(10, 6))

plt.bar(waterfall["region_name"], waterfall["total_revenue"])

plt.title("Source of Revenue Growth")
plt.ylabel("Revenue")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12804\2715181978.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   waterfall = pd.read_sql("SELECT * FROM vw_revenue_by_region", conn)
